# %%
# Load and preview a CSV file using pandas
import pandas as pd

# Load using absolute path
df = pd.read_csv(
    "C:/Users/troyr/OneDrive - Self Taught LLC/PythonDev/03-projects/fred-trade-analysis/data/combined_macro.csv",
    index_col=0,
    parse_dates=True
)

# Preview structure
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 234 entries, 1959-01-01 to 2017-04-01
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GDP           234 non-null    float64
#  1   Net_Exports   234 non-null    float64
#  2   Exports       234 non-null    float64
#  3   Imports       234 non-null    float64
#  4   Gov_Spending  234 non-null    float64
#  5   Savings       234 non-null    float64
#  6   Consumption   234 non-null    float64
# dtypes: float64(7)
# memory usage: 14.6 KB
#                  GDP  Net_Exports  Exports  Imports  Gov_Spending  Savings  \
# 1959-01-01  3352.129        0.519   21.915   21.396       989.449   2426.0
# 1959-04-01  3427.667       -0.768   21.776   22.544      1001.749   2470.0
# 1959-07-01  3430.057        1.211   24.079   22.868      1010.329   2492.0
# 1959-10-01  3439.832        0.627   23.131   22.504      1002.144   2480.6
# ...

# %%
# Summary Statistics
df.describe()
# Out:
#                 GDP  Net_Exports      Exports      Imports  Gov_Spending  \
# count    234.000000   234.000000   234.000000   234.000000    234.000000
# mean   10221.025209  -197.145628   726.710573   923.856205   2048.998756
# std     4868.478647   250.341100   736.673354   962.784853    645.145451
# min     3352.129000  -823.284000    21.776000    21.396000    985.207000
# 25%     6036.342500  -423.246500   100.087000    93.021500   1476.388500
# 50%     9429.048000   -77.085500   429.099000   544.406000   2086.810000
# 75%    14533.093250     0.185250  1083.264750  1523.107250   2725.658000
# max    19506.949000    21.582000  2399.191000  2906.969000   3112.999000
#
#             Savings   Consumption
# count    234.000000    234.000000
# mean    7233.294017   4460.114530
# std     3310.701553   3932.205274
# min     2426.000000    306.100000
# 25%     4479.600000    857.625000
# 50%     6802.750000   3238.350000
# 75%    10355.850000   7423.225000
# ...

# %%
# Missing Values Check
df.isna().sum()
# Out:
# GDP             0
# Net_Exports     0
# Exports         0
# Imports         0
# Gov_Spending    0
# Savings         0
# Consumption     0
# dtype: int64

# %%
# First Plot -- Real GDP
import matplotlib.pyplot as plt

# Rename GDP column for display clarity
df_renamed = df.rename(columns={"GDP": "Real GDP"})

# Plot Real GDP over time
df_renamed["Real GDP"].plot(title="Real GDP Over Time", figsize=(12, 6))
plt.ylabel("Billions of Chained 2012 Dollars")
plt.xlabel("Date")
plt.grid(True)
plt.tight_layout()
plt.show()
